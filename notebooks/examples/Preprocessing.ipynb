# %%
import json

# %%
# Only readable
with open('./data/source/links_201901.json', 'r') as f:
    json_data = json.load(f)

# %%
# Only readable
with open('./data/source/news_texts_10.json', 'r') as f:
    news = json.load(f)

# %%
# news_data = json.loads(news)
news
# Out:
# [{'resource_id': '8fec34e69d8199ad938126de6b30651b',
#   'news_code': '20190101235354271',
#   'url': 'https://v.daum.net/v/20190101235354271',
#   'title': '대피소에서 밤 보내는 주민들',
#   'datetime': '2019-01-01 23:53',
#   'sentences': [' (양양=뉴스1) 서근영 기자 = 1일 강원도 양양군 서면 송천리 일대 야산에서 발생한 산불로 대피한 정다운마을 주민들이 대피소인 상평초등학교에서 밤을 보내고 있다. 2019.1.1/뉴스1',
#    'sky4018@news1.kr',
#    '<저작권자 © 뉴스1코리아, 무단전재 및 재배포 금지> '],
#   'result_code': 1},
#  {'resource_id': '99697c9319f9c4eaadb4eede4d8c5274',
#   'news_code': '20190101235344270',
#   'url': 'https://v.daum.net/v/20190101235344270',
#   'title': '양양 산불로 대피소에서 밤 보내는 주민들',
#   'datetime': '2019-01-01 23:53',
#   'sentences': [' (양양=뉴스1) 서근영 기자 = 1일 강원도 양양군 서면 송천리 일대 야산에서 발생한 산불로 대피한 정다운마을 주민들이 대피소인 상평초등학교에서 밤을 보내고 있다. 2019.1.1/뉴스1',
#    'sky4018@news1.kr',
#    '<저작권자 © 뉴스1코리아, 무단전재 및 재배포 금지> '],
#   'result_code': 1},
#  {'resource_id': 'b42536bd27d079286552221c9f459de4',
#   'news_code': '20190101235323266',
# ...

# %%
data = json.loads(json_data)

# %%
print(data[0])
print()
print(data[-1])
# Out:
# {'resource_id': 'dc4a0e97f038d541df07432abd41c867', 'news_page_info': '20190101-1', 'counts': 15, 'news_codes': ['20190101235354271', '20190101235344270', '20190101235323266', '20190101235315265', '20190101234950238', '20190101234936235', '20190101234818223', '20190101234600210', '20190101234421201', '20190101234342198', '20190101234120183', '20190101234111181', '20190101234051177', '20190101233342133', '20190101232017067'], 'created_at': '2020-02-02 08:48:49'}
#
# {'resource_id': 'bbb9d86fe3017844408ed01132515670', 'news_page_info': '20190131-17', 'counts': 9, 'news_codes': ['20190131030733918', '20190131030048695', '20190131030046693', '20190131030025678', '20190131001256917', '20190131000014631', '20190131000012629', '20190131000012627', '20190131000011626'], 'created_at': '2020-02-02 09:42:46'}

# %%
len(data)
# Out:
# 463
